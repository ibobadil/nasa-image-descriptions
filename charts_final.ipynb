# %%
import csv
import pandas as pd
df = pd.read_csv('nasa_data_keywords.csv')

data = df.sort_values('date_created')
data.value_counts('date_created').plot(kind = 'bar', xlabel = 'Date', ylabel = 'Count', title = 'Image and Video Creation Dates')
# Out:
# <Axes: title={'center': 'Image and Video Creation Dates'}, xlabel='Date', ylabel='Count'>

# %%
data.value_counts('keywords').nlargest(35).plot(kind = 'bar', xlabel = 'Keywords', ylabel = 'Count', title = 'Top 35 Keywords')
# Out:
# <Axes: title={'center': 'Top 35 Keywords'}, xlabel='Keywords', ylabel='Count'>

# %%
data.value_counts('title').nlargest(15).plot(kind = 'bar', xlabel = 'Title', ylabel = 'Count', title = 'Top 15 Keywords')
# Out:
# <Axes: title={'center': 'Top 15 Keywords'}, xlabel='Title', ylabel='Count'>

# %%
data.value_counts('media_type').plot(kind = 'bar', xlabel = 'Media Type', ylabel = 'Count', title = 'Media Types')
# Out:
# <Axes: title={'center': 'Media Types'}, xlabel='Media Type', ylabel='Count'>

# %%
data
# Out:
#      Column                                              title date_created  \
# 26      6.0  MOC Observes Changes in the South Polar Cap: E...   2001-12-11
# 27      NaN  MOC Observes Changes in the South Polar Cap: E...   2001-12-11
# 493     NaN  New Look at Gravity Data Sheds Light on Ocean ...   2009-08-27
# 492    83.0  New Look at Gravity Data Sheds Light on Ocean ...   2009-08-27
# 212     NaN                                  Salt of the Earth   2009-10-12
# ..      ...                                                ...          ...
# 508     NaN  NASA Science Live: Climate Edition - Innovatio...   2024-10-30
# 509     NaN  NASA Science Live: Climate Edition - Innovatio...   2024-10-30
# 510     NaN  NASA Science Live: Climate Edition - Innovatio...   2024-10-30
# 503     NaN  NASA Science Live: Climate Edition - Innovatio...   2024-10-30
# 494    84.0  NASA Science Live: Climate Edition - Innovatio...   2024-10-30
#
# ...

# %%
df
# Out:
#      Column                                              title date_created  \
# 0       0.0  NASA Administrator Bill Nelson | Answering Cli...   2024-09-30
# 1       NaN  NASA Administrator Bill Nelson | Answering Cli...   2024-09-30
# 2       NaN  NASA Administrator Bill Nelson | Answering Cli...   2024-09-30
# 3       1.0  Is Climate Change the Same as Global Warming? ...   2023-07-27
# 4       NaN  Is Climate Change the Same as Global Warming? ...   2023-07-27
# ..      ...                                                ...          ...
# 637     NaN  NASA Evaluates New Threats to Earth’s Ozone Layer   2017-12-08
# 638     NaN  NASA Evaluates New Threats to Earth’s Ozone Layer   2017-12-08
# 639     NaN  NASA Evaluates New Threats to Earth’s Ozone Layer   2017-12-08
# 640     NaN  NASA Evaluates New Threats to Earth’s Ozone Layer   2017-12-08
# 641     NaN  NASA Evaluates New Threats to Earth’s Ozone Layer   2017-12-08
#
#                            keywords media_type  \
# ...
